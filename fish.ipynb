# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KEY")
project = rf.workspace("fish-vdphw").project("fish_detection-z6be1")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/{HOME}/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fish_detection-1 in yolov8:: 100%|██████████| 3462/3462 [00:00<00:00, 7958.51it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=50 imgsz=800 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets
# New https://pypi.org/project/ultralytics/8.3.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/{HOME}/datasets/runs/detect/train/confusion_matrix.png', width=600)

# %%
# %cd {HOME}
Image(filename='/content/{HOME}/datasets/runs/detect/train/results.png', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets

# %%
# %cd {HOME}
Image(filename=f'runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets

# %%
from google.colab import files
import shutil

# Specify the folder you want to download
folder_path = "/content/{HOME}/datasets/runs"

# Zip the folder
shutil.make_archive('/content/runs', 'zip', folder_path)

# Download the zipped folder
files.download('/content/runs.zip')
