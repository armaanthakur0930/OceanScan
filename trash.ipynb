# %%
# Pip install method (recommended)
# !pip uninstall ultralytics

# !pip install ultralytics==8.2.103 -q
# Out:
# WARNING: Skipping ultralytics as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.1/875.1 kB 19.7 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KEY")
project = rf.workspace("object-detect-dmjpt").project("ocean_waste")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/{HOME}/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to ocean_waste-1 in yolov8:: 100%|██████████| 10284/10284 [00:01<00:00, 5890.21it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets
# ...
# 100% 6.25M/6.25M [00:00<00:00, 111MB/s]
# New https://pypi.org/project/ultralytics/8.3.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd {HOME}
Image(filename='/content/{HOME}/datasets/runs/detect/train/confusion_matrix_normalized.png', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets

# %%
# %cd {HOME}
Image(filename='/content/{HOME}/datasets/runs/detect/train/results.png', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets

# %%
# %cd {HOME}
Image(filename='/content/{HOME}/datasets/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/{HOME}/datasets

# %%
from google.colab import files
import shutil

# Specify the folder you want to download
folder_path = "/content/{HOME}/datasets/runs"

# Zip the folder
shutil.make_archive('/content/runs', 'zip', folder_path)

# Download the zipped folder
files.download('/content/runs.zip')
